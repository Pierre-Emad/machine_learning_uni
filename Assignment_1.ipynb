# %% [markdown]
# Name : Pierre Emad Helmy - Computer and Control

# %% [markdown]
# # Assignment
# What is the average battery power of mobile phones in the high price range?

# %%
import pandas as pd
df = pd.read_csv('sample_data/trainsec.csv')
# original data set
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1     NaN           7
# 1              1021     1          0.5         1   0     1.0          53
# 2               563     1          0.5         1   2     1.0          41
# 3               615     1          2.5         0   0     0.0          10
# 4              1821     1          1.2         0  13     NaN          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0     1.0           2
# 1996           1965     1          2.6         1   0     0.0          39
# 1997           1911     0          0.9         1   1     1.0          36
# 1998           1512     0          0.9         0   4     1.0          46
# 1999            510     1          2.0         1   5     1.0          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
high_price_range = df[df['price_range'] == df['price_range'].max()]
# only the high price range phones in the dataset
high_price_range
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1     NaN           7
# 1              1021     1          0.5         1   0     1.0          53
# 2               563     1          0.5         1   2     1.0          41
# 3               615     1          2.5         0   0     0.0          10
# 4              1821     1          1.2         0  13     NaN          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1991           1882     0          2.0         0  11     1.0          44
# 1993           1467     1          0.5         0   0     0.0          18
# 1994            858     0          2.2         0   1     0.0          50
# 1997           1911     0          0.9         1   1     1.0          36
# 1999            510     1          2.0         1   5     1.0          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
high_price_range['battery_power'].mean()
# Out:
# 1375.0511811023623
